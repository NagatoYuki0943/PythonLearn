# %%
from matplotlib import pyplot as plt
from PIL import Image, ImageOps
import requests
import httpx

# %% [markdown]
# # 打开本地图片

# %%
image = Image.open('./image/71479714_p0.jpg')

print(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1048x1654 at 0x20BF1C87C10>

# %% [markdown]
# # 打开网络图片

# %%
response = requests.get("http://images.cocodataset.org/val2017/000000039769.jpg", stream=True)
type(response)
# Out:
# requests.models.Response

# %%
Image.open(requests.get("http://images.cocodataset.org/val2017/000000039769.jpg", stream=True).raw).convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>

# %%
response = httpx.get("http://images.cocodataset.org/val2017/000000039769.jpg")
type(response)
# Out:
# httpx.Response

# %%
Image.open(httpx.get("http://images.cocodataset.org/val2017/000000039769.jpg")).convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>

# %% [markdown]
# # 图像有时会自动旋转，这样可以保证角度相同

# %%
# 恢复正常角度的图像
image = ImageOps.exif_transpose(image)

# %% [markdown]
# # 显示图片

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=1048x1654>

# %%
image.show()

# %% [markdown]
# # 保存图片,可以更改格式

# %%
image.save('./image/71479714_p0.png')

# %% [markdown]
# # plt画图

# %%
plt.figure(figsize=(10,8))
plt.axis('off') # 不显示坐标轴
plt.title('黄前久美子')
plt.imshow(image)
# 解决中文显示问题
plt.rcParams['font.sans-serif'] = ['KaiTi']  # 指定默认字体
plt.rcParams['axes.unicode_minus'] = False  # 解决保存图像是负号'-'显示为方块的问题
plt.show()

# %%
print(type(image))
print(image.size)  				# 图片的尺寸 width height
print(image.height)             # 1654
print(image.width)              # 1048
print(image.mode)  				# 图片的模式
print(image.format)  			# 图片的格式
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# (1048, 1654)
# 1654
# 1048
# RGB
# JPEG

# %% [markdown]
# # image.getpixel((宽, 高))

# %%
print(image.getpixel((0,0)))	#得到像素
# Out:
# (188, 225, 254)
