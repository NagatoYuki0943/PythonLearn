# %%
import os

from matplotlib import pyplot as plt

from PIL import Image, ImageDraw, ImageFont

# %% [markdown]
# # 导入图片

# %%
image = Image.open('./image/71479714_p0.jpg')

print(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1048x1654 at 0x23280F1EA30>

# %% [markdown]
# # 画图 ImageDraw

# %%
draw = ImageDraw.Draw(image)
#获取图像的宽和高
width, height = image.size

# %% [markdown]
# # 文字字体 ImageFont

# %%
#选择文字字体和大小
setFont = ImageFont.truetype('C:/windows/fonts/Dengl.ttf', 20)
#设置文字颜色
fillColor = "blue"
#写入文字
draw.text((40, height - 100), u'黄前久美子,黄大叔', font=setFont, fill=fillColor)

# %%
plt.figure(figsize=(9,16))
plt.axis('off') # 不显示坐标轴
plt.imshow(image)
plt.show()
