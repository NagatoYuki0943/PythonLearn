# %%
import os

from matplotlib import pyplot as plt

from PIL import Image
import numpy as np

# %% [markdown]
# # 打开图片

# %%
image = Image.open("./image/71479714_p0.jpg")

# %% [markdown]
# # 将 PIL Image 图片转换为 numpy 数组 np.array(image)

# %%
img = np.array(image)
img
# Out:
# array([[[188, 225, 254],
#         [188, 225, 254],
#         [188, 225, 254],
#         ...,
#         [188, 225, 254],
#         [188, 225, 254],
#         [188, 225, 254]],
#
#        [[188, 225, 254],
#         [188, 225, 254],
#         [188, 225, 254],
#         ...,
#         [188, 225, 254],
#         [188, 225, 254],
#         [188, 225, 254]],
#
#        [[188, 225, 254],
#         [188, 225, 254],
#         [188, 225, 254],
#         ...,
#         [188, 225, 254],
#         [188, 225, 254],
#         [188, 225, 254]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %% [markdown]
# # numpy image 查看图片信息 .shape .dtype

# %%
print(img.shape)
print(img.dtype)
# Out:
# (1654, 1048, 3)
# uint8

# %% [markdown]
# # numpy数据可以直接被画图 通道为 [高, 宽, 通道]

# %%
plt.figure(figsize=(9, 16))
plt.imshow(img)
plt.axis("off")
plt.show()

# %% [markdown]
# # 将 numpy 数组转换为 PIL 图片  Image.fromarray(数组)

# %%
new_img = Image.fromarray(img)

plt.figure(figsize=(9, 16))
plt.imshow(new_img)
plt.axis("off")
plt.show()

# %% [markdown]
# # numpy高级操作

# %% [markdown]
# ## 添加噪声

# %%
image = Image.open("./image/71479714_p0.jpg")
img = np.array(image)

# 随机生成5000个椒盐
rows, cols, dims = img.shape
for i in range(5000):
    x = np.random.randint(0, rows)
    y = np.random.randint(0, cols)
    img[x, y, :] = 255

plt.figure(figsize=(9, 16))
plt.imshow(img)
plt.axis("off")
plt.show()

# %% [markdown]
# # 二值化处理

# %%
image = Image.open("./image/71479714_p0.jpg")
#                 黑白图片
image = image.convert("L")
img = np.array(image)
img
# Out:
# array([[217, 217, 217, ..., 217, 217, 217],
#        [217, 217, 217, ..., 217, 217, 217],
#        [217, 217, 217, ..., 217, 217, 217],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
rows, cols = img.shape
for i in range(rows):
    for j in range(cols):
        if img[i, j] <= 128:
            img[i, j] = 0
        else:
            img[i, j] = 1

# %%
plt.figure(figsize=(9, 16))
#         直接使用numpy数组就能输出
plt.imshow(img, cmap="gray")
plt.axis("off")
plt.show()

# %% [markdown]
# # 切片处理灰度值

# %%
image = Image.open("./image/71479714_p0.jpg")
#                 黑白图片
image = image.convert("L")
img = np.array(image)
img
# Out:
# array([[217, 217, 217, ..., 217, 217, 217],
#        [217, 217, 217, ..., 217, 217, 217],
#        [217, 217, 217, ..., 217, 217, 217],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
i, j = 20, 40
img[i, :] = img[j, :]  # 将第 j 行的数值赋值给第 i 行
img[:, i] = 100  # 将第 i 列的所有数值设为 100
img[:100, :50].sum()  # 计算前 100 行、前 50 列所有数值的和
img[50:100, 50:100]  # 50~100 行，50~100 列（不包括第 100 行和第 100 列）
img[i].mean()  # 第 i 行所有数值的平均值
img[:, -1]  # 最后一列
img[-2, :]  # 倒数第二行
img
# Out:
# array([[217, 217, 217, ..., 217, 217, 217],
#        [217, 217, 217, ..., 217, 217, 217],
#        [217, 217, 217, ..., 217, 217, 217],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [217, 217, 217, ..., 255, 255, 255]], dtype=uint8)

# %%
plt.figure(figsize=(9, 16))
#         直接使用numpy数组就能输出
plt.imshow(img)
plt.axis("off")
plt.show()
